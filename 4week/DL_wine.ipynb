# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/winequality-white.csv", sep=";")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# 레이블 갯수 확인 (그래프)
sns.countplot(data = df, x="quality")
plt.xlabel("quality")
plt.ylabel("Count")
plt.title("quality")
# Out:
# Text(0.5, 1.0, 'quality')

# %%
# 레이블 갯수 확인 (숫자)
df['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
X = df.drop(columns=["quality"])
y_raw = df["quality"].copy()

# %%
le = LabelEncoder()
y = le.fit_transform(y_raw)
classes = le.classes_
print("Class mapping (original -> encoded):")
for orig, enc in zip(classes, range(len(classes))):
    print(f"  {orig} -> {enc}")
print()
# Out:
# Class mapping (original -> encoded):
#   3 -> 0
#   4 -> 1
#   5 -> 2
#   6 -> 3
#   7 -> 4
#   8 -> 5
#   9 -> 6

# %%
Y = pd.get_dummies(y).values
X = X.values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc  = scaler.transform(X_test)

# %%
inputs = tf.keras.Input(shape=(X_train_sc.shape[1],))

x = tf.keras.layers.Dense(128)(inputs)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Dropout(0.30)(x)

x = tf.keras.layers.Dense(64)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Dropout(0.30)(x)

x = tf.keras.layers.Dense(32)(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Dropout(0.20)(x)

# %%
outputs = tf.keras.layers.Dense(7, activation="softmax")(x)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 11)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_7 (ReLU)                  │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,871 (50.28 KB)
#  Trainable params: 12,487 (48.78 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 11)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_7 (ReLU)                  │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,871 (50.28 KB)
#  Trainable params: 12,487 (48.78 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=12,
    min_delta=1e-4,
    restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=6,
    min_lr=1e-5,
    verbose=1
)

# %%
history = model.fit(
    X_train_sc, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    shuffle=True,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.2617 - loss: 2.0072 - val_accuracy: 0.5293 - val_loss: 1.3857 - learning_rate: 0.0010
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4910 - loss: 1.2862 - val_accuracy: 0.5268 - val_loss: 1.1969 - learning_rate: 0.0010
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5034 - loss: 1.2302 - val_accuracy: 0.5383 - val_loss: 1.1216 - learning_rate: 0.0010
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5152 - loss: 1.1574 - val_accuracy: 0.5281 - val_loss: 1.0920 - learning_rate: 0.0010
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5104 - loss: 1.1615 - val_accuracy: 0.5395 - val_loss: 1.0641 - learning_rate: 0.0010
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5074 - loss: 1.1378 - val_accuracy: 0.5548 - val_loss: 1.0477 - learning_rate: 0.0010
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5041 - loss: 1.1077 - val_accuracy: 0.5523 - val_loss: 1.0336 - learning_rate: 0.0010
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5418 - loss: 1.0792 - val_accuracy: 0.5676 - val_loss: 1.0273 - learning_rate: 0.0010
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5274 - loss: 1.1043 - val_accuracy: 0.5625 - val_loss: 1.0238 - learning_rate: 0.0010
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5427 - loss: 1.0743 - val_accuracy: 0.5574 - val_loss: 1.0162 - learning_rate: 0.0010
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5443 - loss: 1.0816 - val_accuracy: 0.5459 - val_loss: 1.0144 - learning_rate: 0.0010
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5533 - loss: 1.0786 - val_accuracy: 0.5510 - val_loss: 1.0102 - learning_rate: 0.0010
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5086 - loss: 1.0764 - val_accuracy: 0.5574 - val_loss: 1.0096 - learning_rate: 0.0010
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5552 - loss: 1.0446 - val_accuracy: 0.5497 - val_loss: 1.0052 - learning_rate: 0.0010
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5605 - loss: 1.0615 - val_accuracy: 0.5459 - val_loss: 1.0034 - learning_rate: 0.0010
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5544 - loss: 1.0336 - val_accuracy: 0.5663 - val_loss: 0.9975 - learning_rate: 0.0010
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5505 - loss: 1.0495 - val_accuracy: 0.5676 - val_loss: 0.9943 - learning_rate: 0.0010
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5429 - loss: 1.0405 - val_accuracy: 0.5612 - val_loss: 0.9940 - learning_rate: 0.0010
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5549 - loss: 1.0268 - val_accuracy: 0.5574 - val_loss: 1.0014 - learning_rate: 0.0010
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5503 - loss: 1.0607 - val_accuracy: 0.5561 - val_loss: 0.9951 - learning_rate: 0.0010
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5494 - loss: 1.0531 - val_accuracy: 0.5651 - val_loss: 0.9962 - learning_rate: 0.0010
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5561 - loss: 1.0425 - val_accuracy: 0.5599 - val_loss: 0.9879 - learning_rate: 0.0010
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5755 - loss: 1.0200 - val_accuracy: 0.5638 - val_loss: 0.9936 - learning_rate: 0.0010
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5448 - loss: 1.0416 - val_accuracy: 0.5676 - val_loss: 0.9902 - learning_rate: 0.0010
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5643 - loss: 1.0280 - val_accuracy: 0.5663 - val_loss: 0.9923 - learning_rate: 0.0010
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5453 - loss: 1.0299 - val_accuracy: 0.5727 - val_loss: 0.9928 - learning_rate: 0.0010
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5730 - loss: 1.0001 - val_accuracy: 0.5561 - val_loss: 0.9936 - learning_rate: 0.0010
# Epoch 28/100
# 91/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5533 - loss: 1.0199
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5528 - loss: 1.0207 - val_accuracy: 0.5599 - val_loss: 0.9985 - learning_rate: 0.0010
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5452 - loss: 1.0337 - val_accuracy: 0.5548 - val_loss: 0.9934 - learning_rate: 5.0000e-04
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5562 - loss: 1.0217 - val_accuracy: 0.5702 - val_loss: 0.9868 - learning_rate: 5.0000e-04
# Epoch 31/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5838 - loss: 1.0049 - val_accuracy: 0.5714 - val_loss: 0.9893 - learning_rate: 5.0000e-04
# Epoch 32/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5623 - loss: 1.0142 - val_accuracy: 0.5536 - val_loss: 0.9863 - learning_rate: 5.0000e-04
# Epoch 33/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5719 - loss: 0.9960 - val_accuracy: 0.5676 - val_loss: 0.9822 - learning_rate: 5.0000e-04
# Epoch 34/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5666 - loss: 1.0214 - val_accuracy: 0.5612 - val_loss: 0.9845 - learning_rate: 5.0000e-04
# Epoch 35/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5626 - loss: 0.9947 - val_accuracy: 0.5702 - val_loss: 0.9848 - learning_rate: 5.0000e-04
# Epoch 36/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5716 - loss: 1.0166 - val_accuracy: 0.5714 - val_loss: 0.9845 - learning_rate: 5.0000e-04
# Epoch 37/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5597 - loss: 0.9886 - val_accuracy: 0.5651 - val_loss: 0.9847 - learning_rate: 5.0000e-04
# Epoch 38/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5666 - loss: 0.9890 - val_accuracy: 0.5638 - val_loss: 0.9830 - learning_rate: 5.0000e-04
# Epoch 39/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5542 - loss: 0.9938 - val_accuracy: 0.5689 - val_loss: 0.9809 - learning_rate: 5.0000e-04
# Epoch 40/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5657 - loss: 0.9980 - val_accuracy: 0.5676 - val_loss: 0.9828 - learning_rate: 5.0000e-04
# Epoch 41/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5859 - loss: 0.9872 - val_accuracy: 0.5663 - val_loss: 0.9827 - learning_rate: 5.0000e-04
# Epoch 42/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5884 - loss: 0.9679 - val_accuracy: 0.5740 - val_loss: 0.9814 - learning_rate: 5.0000e-04
# Epoch 43/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5441 - loss: 1.0154 - val_accuracy: 0.5663 - val_loss: 0.9822 - learning_rate: 5.0000e-04
# Epoch 44/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5628 - loss: 1.0012 - val_accuracy: 0.5702 - val_loss: 0.9831 - learning_rate: 5.0000e-04
# Epoch 45/100
# 86/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5658 - loss: 1.0140
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5665 - loss: 1.0128 - val_accuracy: 0.5663 - val_loss: 0.9809 - learning_rate: 5.0000e-04
# Epoch 46/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5726 - loss: 0.9741 - val_accuracy: 0.5702 - val_loss: 0.9806 - learning_rate: 2.5000e-04
# Epoch 47/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5650 - loss: 1.0107 - val_accuracy: 0.5651 - val_loss: 0.9777 - learning_rate: 2.5000e-04
# Epoch 48/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5689 - loss: 0.9826 - val_accuracy: 0.5612 - val_loss: 0.9775 - learning_rate: 2.5000e-04
# Epoch 49/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5605 - loss: 1.0120 - val_accuracy: 0.5663 - val_loss: 0.9768 - learning_rate: 2.5000e-04
# Epoch 50/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5683 - loss: 0.9728 - val_accuracy: 0.5676 - val_loss: 0.9766 - learning_rate: 2.5000e-04
# Epoch 51/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5759 - loss: 0.9897 - val_accuracy: 0.5714 - val_loss: 0.9775 - learning_rate: 2.5000e-04
# Epoch 52/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5917 - loss: 0.9876 - val_accuracy: 0.5689 - val_loss: 0.9778 - learning_rate: 2.5000e-04
# Epoch 53/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5741 - loss: 0.9841 - val_accuracy: 0.5727 - val_loss: 0.9762 - learning_rate: 2.5000e-04
# Epoch 54/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5745 - loss: 1.0051 - val_accuracy: 0.5676 - val_loss: 0.9774 - learning_rate: 2.5000e-04
# Epoch 55/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5726 - loss: 0.9902 - val_accuracy: 0.5663 - val_loss: 0.9785 - learning_rate: 2.5000e-04
# Epoch 56/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5761 - loss: 0.9981 - val_accuracy: 0.5689 - val_loss: 0.9780 - learning_rate: 2.5000e-04
# Epoch 57/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5719 - loss: 0.9733 - val_accuracy: 0.5689 - val_loss: 0.9769 - learning_rate: 2.5000e-04
# Epoch 58/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5737 - loss: 1.0005 - val_accuracy: 0.5676 - val_loss: 0.9780 - learning_rate: 2.5000e-04
# Epoch 59/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5556 - loss: 0.9996 - val_accuracy: 0.5727 - val_loss: 0.9758 - learning_rate: 2.5000e-04
# Epoch 60/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5741 - loss: 0.9797 - val_accuracy: 0.5689 - val_loss: 0.9758 - learning_rate: 2.5000e-04
# Epoch 61/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5585 - loss: 0.9970 - val_accuracy: 0.5727 - val_loss: 0.9753 - learning_rate: 2.5000e-04
# Epoch 62/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5713 - loss: 0.9861 - val_accuracy: 0.5753 - val_loss: 0.9752 - learning_rate: 2.5000e-04
# Epoch 63/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5532 - loss: 1.0074 - val_accuracy: 0.5740 - val_loss: 0.9775 - learning_rate: 2.5000e-04
# Epoch 64/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5795 - loss: 0.9944 - val_accuracy: 0.5702 - val_loss: 0.9768 - learning_rate: 2.5000e-04
# Epoch 65/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5766 - loss: 0.9663 - val_accuracy: 0.5778 - val_loss: 0.9776 - learning_rate: 2.5000e-04
# Epoch 66/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5769 - loss: 0.9810 - val_accuracy: 0.5676 - val_loss: 0.9779 - learning_rate: 2.5000e-04
# Epoch 67/100
# 88/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5718 - loss: 0.9878
# Epoch 67: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5721 - loss: 0.9877 - val_accuracy: 0.5778 - val_loss: 0.9768 - learning_rate: 2.5000e-04
# Epoch 68/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5587 - loss: 1.0155 - val_accuracy: 0.5791 - val_loss: 0.9758 - learning_rate: 1.2500e-04
# Epoch 69/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5661 - loss: 0.9980 - val_accuracy: 0.5727 - val_loss: 0.9768 - learning_rate: 1.2500e-04
# Epoch 70/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5436 - loss: 0.9919 - val_accuracy: 0.5765 - val_loss: 0.9766 - learning_rate: 1.2500e-04
# Epoch 71/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5831 - loss: 0.9777 - val_accuracy: 0.5753 - val_loss: 0.9777 - learning_rate: 1.2500e-04
# Epoch 72/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5930 - loss: 0.9597 - val_accuracy: 0.5727 - val_loss: 0.9780 - learning_rate: 1.2500e-04
# Epoch 73/100
# 89/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5819 - loss: 0.9709
# Epoch 73: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5813 - loss: 0.9739 - val_accuracy: 0.5765 - val_loss: 0.9768 - learning_rate: 1.2500e-04

# %%
y_pred = model.predict(X_test_sc)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report
print("Acc:", accuracy_score(y_test_class, y_pred_class))
print("F1(macro):", f1_score(y_test_class, y_pred_class, average="macro"))
print(classification_report(y_test_class, y_pred_class))
# Out:
# Acc: 0.5428571428571428
# F1(macro): 0.2953903728826858
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       1.00      0.08      0.15        51
#            2       0.57      0.60      0.59       295
#            3       0.52      0.69      0.59       409
#            4       0.55      0.38      0.45       183
#            5       0.00      0.00      0.00        33
#
#     accuracy                           0.54       980
#    macro avg       0.44      0.29      0.30       980
# weighted avg       0.54      0.54      0.52       980
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.figure(figsize=(6,4))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(6,4))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

print("=== Classification Report ===")
print(classification_report(y_test_class, y_pred_class))
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       1.00      0.08      0.15        51
#            2       0.57      0.60      0.59       295
#            3       0.52      0.69      0.59       409
#            4       0.55      0.38      0.45       183
#            5       0.00      0.00      0.00        33
#
#     accuracy                           0.54       980
#    macro avg       0.44      0.29      0.30       980
# weighted avg       0.54      0.54      0.52       980
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
cm = confusion_matrix(y_test_class, y_pred_class)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test_class),
            yticklabels=np.unique(y_test_class))
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
