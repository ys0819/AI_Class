# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/breast_cancer.csv", header=0, index_col=0).dropna()
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  label
# 0                  0.2654          0.4601                  0.11890      0
# 1                  0.1860          0.2750                  0.08902      0
# 2                  0.2430          0.3613                  0.08758      0
# 3                  0.2575          0.6638                  0.17300      0
# 4                  0.1625          0.2364                  0.07678      0
# ..                    ...             ...                      ...    ...
# 564                0.2216          0.2060                  0.07115      0
# 565                0.1628          0.2572                  0.06637      0
# 566                0.1418          0.2218                  0.07820      0
# 567                0.2650          0.4087                  0.12400      0
# 568                0.0000          0.2871                  0.07039      1
#
# [569 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'label'],
#       dtype='object')

# %%
# 레이블 갯수 확인 (그래프)
sns.countplot(data = df, x="label")
plt.xlabel("label")
plt.ylabel("Count")
plt.title("label")
# Out:
# Text(0.5, 1.0, 'label')

# %%
# 레이블 갯수 확인 (숫자)
df['label'].value_counts()
# Out:
# label
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
X = df.drop(columns=["label"])
y = df["label"]

# %%
Y = pd.get_dummies(y).values
X = X.values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc  = scaler.transform(X_test)

# %%
inputs = tf.keras.Input(shape=(X_train_sc.shape[1],))

x = tf.keras.layers.Dense(128)(inputs)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Dropout(0.30)(x)

x = tf.keras.layers.Dense(64)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Dropout(0.30)(x)

x = tf.keras.layers.Dense(32)(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Dropout(0.20)(x)

# %%
outputs = tf.keras.layers.Dense(2, activation="sigmoid")(x)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         3,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,138 (59.13 KB)
#  Trainable params: 14,754 (57.63 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="binary_crossentropy",
    metrics=['accuracy'])

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=12,
    min_delta=1e-4,
    restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=6,
    min_lr=1e-5,
    verbose=1
)

# %%
history = model.fit(
    X_train_sc, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    shuffle=True,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.6147 - loss: 0.6882 - val_accuracy: 0.9780 - val_loss: 0.4804 - learning_rate: 0.0010
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8310 - loss: 0.4764 - val_accuracy: 0.9780 - val_loss: 0.3593 - learning_rate: 0.0010
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9546 - loss: 0.3404 - val_accuracy: 0.9780 - val_loss: 0.2705 - learning_rate: 0.0010
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9435 - loss: 0.2576 - val_accuracy: 0.9780 - val_loss: 0.2105 - learning_rate: 0.0010
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9421 - loss: 0.2262 - val_accuracy: 0.9890 - val_loss: 0.1705 - learning_rate: 0.0010
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9528 - loss: 0.1823 - val_accuracy: 0.9780 - val_loss: 0.1437 - learning_rate: 0.0010
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9653 - loss: 0.1499 - val_accuracy: 0.9890 - val_loss: 0.1233 - learning_rate: 0.0010
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9739 - loss: 0.1307 - val_accuracy: 0.9670 - val_loss: 0.1074 - learning_rate: 0.0010
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9554 - loss: 0.1287 - val_accuracy: 0.9780 - val_loss: 0.0941 - learning_rate: 0.0010
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9420 - loss: 0.1504 - val_accuracy: 0.9670 - val_loss: 0.0826 - learning_rate: 0.0010
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9699 - loss: 0.1140 - val_accuracy: 0.9670 - val_loss: 0.0760 - learning_rate: 0.0010
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9680 - loss: 0.1145 - val_accuracy: 0.9780 - val_loss: 0.0699 - learning_rate: 0.0010
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9851 - loss: 0.0836 - val_accuracy: 0.9780 - val_loss: 0.0640 - learning_rate: 0.0010
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9552 - loss: 0.1271 - val_accuracy: 0.9890 - val_loss: 0.0588 - learning_rate: 0.0010
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9732 - loss: 0.0965 - val_accuracy: 0.9890 - val_loss: 0.0574 - learning_rate: 0.0010
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9528 - loss: 0.1254 - val_accuracy: 0.9890 - val_loss: 0.0556 - learning_rate: 0.0010
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9691 - loss: 0.0960 - val_accuracy: 0.9780 - val_loss: 0.0537 - learning_rate: 0.0010
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9652 - loss: 0.0978 - val_accuracy: 0.9890 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9682 - loss: 0.0896 - val_accuracy: 0.9780 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9636 - loss: 0.0982 - val_accuracy: 0.9890 - val_loss: 0.0497 - learning_rate: 0.0010
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9843 - loss: 0.0790 - val_accuracy: 0.9890 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9855 - loss: 0.0762 - val_accuracy: 0.9890 - val_loss: 0.0462 - learning_rate: 0.0010
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9530 - loss: 0.1600 - val_accuracy: 0.9890 - val_loss: 0.0459 - learning_rate: 0.0010
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9615 - loss: 0.0968 - val_accuracy: 0.9890 - val_loss: 0.0453 - learning_rate: 0.0010
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9777 - loss: 0.0736 - val_accuracy: 0.9890 - val_loss: 0.0431 - learning_rate: 0.0010
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9653 - loss: 0.0887 - val_accuracy: 0.9780 - val_loss: 0.0416 - learning_rate: 0.0010
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9658 - loss: 0.0806 - val_accuracy: 0.9780 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9610 - loss: 0.1200 - val_accuracy: 0.9780 - val_loss: 0.0418 - learning_rate: 0.0010
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9947 - loss: 0.0450 - val_accuracy: 0.9890 - val_loss: 0.0405 - learning_rate: 0.0010
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9766 - loss: 0.0796 - val_accuracy: 1.0000 - val_loss: 0.0372 - learning_rate: 0.0010
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9734 - loss: 0.0810 - val_accuracy: 1.0000 - val_loss: 0.0371 - learning_rate: 0.0010
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9772 - loss: 0.0943 - val_accuracy: 1.0000 - val_loss: 0.0389 - learning_rate: 0.0010
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9768 - loss: 0.0641 - val_accuracy: 0.9890 - val_loss: 0.0376 - learning_rate: 0.0010
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9759 - loss: 0.0679 - val_accuracy: 0.9890 - val_loss: 0.0374 - learning_rate: 0.0010
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9776 - loss: 0.0516 - val_accuracy: 0.9890 - val_loss: 0.0419 - learning_rate: 0.0010
# Epoch 36/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0315
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9833 - loss: 0.0636 - val_accuracy: 1.0000 - val_loss: 0.0393 - learning_rate: 0.0010
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9816 - loss: 0.0538 - val_accuracy: 1.0000 - val_loss: 0.0381 - learning_rate: 5.0000e-04
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9839 - loss: 0.0568 - val_accuracy: 0.9890 - val_loss: 0.0356 - learning_rate: 5.0000e-04
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9630 - loss: 0.0939 - val_accuracy: 0.9890 - val_loss: 0.0349 - learning_rate: 5.0000e-04
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9780 - loss: 0.0675 - val_accuracy: 0.9890 - val_loss: 0.0343 - learning_rate: 5.0000e-04
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9743 - loss: 0.0859 - val_accuracy: 1.0000 - val_loss: 0.0330 - learning_rate: 5.0000e-04
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9817 - loss: 0.0594 - val_accuracy: 1.0000 - val_loss: 0.0317 - learning_rate: 5.0000e-04
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9857 - loss: 0.0450 - val_accuracy: 1.0000 - val_loss: 0.0306 - learning_rate: 5.0000e-04
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9818 - loss: 0.0573 - val_accuracy: 1.0000 - val_loss: 0.0311 - learning_rate: 5.0000e-04
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9839 - loss: 0.0546 - val_accuracy: 1.0000 - val_loss: 0.0314 - learning_rate: 5.0000e-04
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9800 - loss: 0.0590 - val_accuracy: 1.0000 - val_loss: 0.0305 - learning_rate: 5.0000e-04
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9661 - loss: 0.0799 - val_accuracy: 1.0000 - val_loss: 0.0288 - learning_rate: 5.0000e-04
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9801 - loss: 0.0521 - val_accuracy: 1.0000 - val_loss: 0.0278 - learning_rate: 5.0000e-04
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9584 - loss: 0.0781 - val_accuracy: 1.0000 - val_loss: 0.0286 - learning_rate: 5.0000e-04
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9796 - loss: 0.0691 - val_accuracy: 1.0000 - val_loss: 0.0305 - learning_rate: 5.0000e-04
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9804 - loss: 0.0578 - val_accuracy: 0.9890 - val_loss: 0.0307 - learning_rate: 5.0000e-04
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9694 - loss: 0.0793 - val_accuracy: 1.0000 - val_loss: 0.0295 - learning_rate: 5.0000e-04
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9709 - loss: 0.0612 - val_accuracy: 1.0000 - val_loss: 0.0271 - learning_rate: 5.0000e-04
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9536 - loss: 0.1009 - val_accuracy: 1.0000 - val_loss: 0.0263 - learning_rate: 5.0000e-04
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9937 - loss: 0.0428 - val_accuracy: 1.0000 - val_loss: 0.0270 - learning_rate: 5.0000e-04
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9666 - loss: 0.0811 - val_accuracy: 1.0000 - val_loss: 0.0270 - learning_rate: 5.0000e-04
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9865 - loss: 0.0494 - val_accuracy: 1.0000 - val_loss: 0.0269 - learning_rate: 5.0000e-04
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9910 - loss: 0.0392 - val_accuracy: 1.0000 - val_loss: 0.0268 - learning_rate: 5.0000e-04
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9806 - loss: 0.0472 - val_accuracy: 1.0000 - val_loss: 0.0266 - learning_rate: 5.0000e-04
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9823 - loss: 0.0560 - val_accuracy: 1.0000 - val_loss: 0.0254 - learning_rate: 5.0000e-04
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9714 - loss: 0.0822 - val_accuracy: 1.0000 - val_loss: 0.0267 - learning_rate: 5.0000e-04
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9896 - loss: 0.0390 - val_accuracy: 1.0000 - val_loss: 0.0268 - learning_rate: 5.0000e-04
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9696 - loss: 0.0685 - val_accuracy: 1.0000 - val_loss: 0.0257 - learning_rate: 5.0000e-04
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9923 - loss: 0.0326 - val_accuracy: 1.0000 - val_loss: 0.0256 - learning_rate: 5.0000e-04
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9892 - loss: 0.0507 - val_accuracy: 1.0000 - val_loss: 0.0248 - learning_rate: 5.0000e-04
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9867 - loss: 0.0495 - val_accuracy: 1.0000 - val_loss: 0.0241 - learning_rate: 5.0000e-04
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9676 - loss: 0.0906 - val_accuracy: 1.0000 - val_loss: 0.0251 - learning_rate: 5.0000e-04
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9768 - loss: 0.0514 - val_accuracy: 1.0000 - val_loss: 0.0265 - learning_rate: 5.0000e-04
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9938 - loss: 0.0406 - val_accuracy: 1.0000 - val_loss: 0.0299 - learning_rate: 5.0000e-04
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9790 - loss: 0.0613 - val_accuracy: 1.0000 - val_loss: 0.0320 - learning_rate: 5.0000e-04
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9832 - loss: 0.0498 - val_accuracy: 1.0000 - val_loss: 0.0318 - learning_rate: 5.0000e-04
# Epoch 72/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0406
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9773 - loss: 0.0635 - val_accuracy: 1.0000 - val_loss: 0.0300 - learning_rate: 5.0000e-04
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9894 - loss: 0.0394 - val_accuracy: 1.0000 - val_loss: 0.0293 - learning_rate: 2.5000e-04
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9873 - loss: 0.0399 - val_accuracy: 1.0000 - val_loss: 0.0291 - learning_rate: 2.5000e-04
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9842 - loss: 0.0521 - val_accuracy: 1.0000 - val_loss: 0.0293 - learning_rate: 2.5000e-04
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9667 - loss: 0.0816 - val_accuracy: 1.0000 - val_loss: 0.0288 - learning_rate: 2.5000e-04
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9779 - loss: 0.0623 - val_accuracy: 1.0000 - val_loss: 0.0281 - learning_rate: 2.5000e-04
# Epoch 78/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0416
# Epoch 78: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9963 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 0.0281 - learning_rate: 2.5000e-04

# %%
y_pred = model.predict(X_test_sc)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report
print("Acc:", accuracy_score(y_test_class, y_pred_class))
print("F1(macro):", f1_score(y_test_class, y_pred_class, average="macro"))
print(classification_report(y_test_class, y_pred_class))
# Out:
# Acc: 0.9912280701754386
# F1(macro): 0.9909774436090225
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        47
#            1       1.00      0.99      0.99        67
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.figure(figsize=(6,4))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(6,4))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

print("=== Classification Report ===")
print(classification_report(y_test_class, y_pred_class))
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        47
#            1       1.00      0.99      0.99        67
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114

# %%
cm = confusion_matrix(y_test_class, y_pred_class)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=np.unique(y_test_class),
            yticklabels=np.unique(y_test_class))
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
